# %%
import pandas as pd

# %%
import plotly.plotly as py
import plotly.offline as of
import plotly.graph_objs as go
of.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import plotly.tools as tls
tls.set_credentials_file(username='Nikita1988', api_key='TZXSpGC7ttUxdqqzYsep')

# %%
#input_file=r'C:\Users\User\workspace_mars\MFree\phi.dat'
input_file=r'..\phi.dat'

# %%
#1x,'Node', 5x,'x', 7x,'y', 8x,'Phi', 6x,'dPhidx', &
#        5x,'dPhidy', 4x, 'dPhidxx', 4x,'dPhidyy
df=pd.read_fwf(input_file, widths=[5,8,8,12,12,11,11,10,10,10], skiprows=[1],na_values='-----', skipinitialspace =True)
df=df.dropna()

# %%
df.head(5)
# Out:
#    Node       x       y      Phi    dPhidx    dPhidy   dPhidxx   dPhidyy  \
# 0   1.0  -1.000  -1.000  0.87245  -1.48251  -1.48251   0.33736   0.33736
# 1   2.0  -1.000  -0.500  0.12755  -0.51749   1.48251  -0.33736  -0.33736
# 2   3.0  -1.000   0.000  0.00000   0.00000   0.00000   0.00000   0.00000
# 3   4.0  -1.000   0.500  0.00000   0.00000   0.00000   0.00000   0.00000
# 4   5.0  -1.000   1.000  0.00000   0.00000   0.00000   0.00000   0.00000
#
#       GposX  GposY
# 0  -1.00000   -1.0
# 1  -1.00000   -1.0
# 2  -1.00000   -1.0
# 3  -1.00000   -1.0
# 4  -1.00000   -1.0

# %%
df.x=pd.to_numeric(df.x)
df.y=pd.to_numeric(df.y)
df.Phi=pd.to_numeric(df.Phi)
df.GposX=pd.to_numeric(df.GposX)

# %%
z1=df[(df.Node==13) ]

# %%
z2=z1.pivot(index='GposY', columns='GposX', values='dPhidxx')

# %%
trace=go.Surface(z=z2.as_matrix(), colorscale='Virdis', )
data=[trace]
layout = go.Layout(
    autosize=False,
    width=800,
    height=800,)
fig=go.Figure(data=data, layout=layout)

of.iplot(fig)
# Out:
# <div id="d9567719-4086-4cc2-9211-6b311afe4e9d" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d9567719-4086-4cc2-9211-6b311afe4e9d", [{"type": "surface", "colorscale": "Virdis", "z": [["0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000", "0.00000"], ["0.00000", "-0.00003", "-0.00005", "-0.00004", "-0.00003", "-0.00002", "-0.00002", "-0.00003", "-0.00004", "-0.00006", "-0.00008", "-0.00010", "-0.00012", "-0.00013", "-0.00014", "-0.00015", "-0.00011", "-0.00007", "-0.00003", "0.00001", "0.00004", "0.00006", "0.00009", "0.00011", "0.00012", "0.00013", "0.00014", "0.00015", "0.00016", "0.00017", "0.00018", "0.00017", "0.00016", "0.00015", "0.00014", "0.00013", "0.00012", "0.00011", "0.00009", "0.00006", "0.00004", "0.00001", "-0.00003", "-0.00007", "-0.00011", "-0.00015", "-0.00014", "-0.00013", "-0.00012", "-0.00010", "-0.00008", "-0.00006", "-0.00004", "-0.00003", "-0.00002", "-0.00002", "-0.00003", "-0.00004", "-0